# %% [markdown]
# # Client behavior analysis

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# merge dataframes sample_client with experiment clients

df_sample_client = df_sample_client.merge(df_exp, on='client_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 3
#       1 # merge dataframes sample_client with experiment clients
# ----> 3 df_sample_client = df_sample_client.merge(df_exp, on='client_id', how='left')
#
# NameError: name 'df_sample_client' is not defined

# %%
df_sample_client.columns = df_sample_client.columns.str.lower()

# %%
display(df_sample_client) # df_sample_client
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50481    1780858            21.0             262.0      68.5     M        3.0
# 50482    6967120            21.0             260.0      68.5     M        3.0
# 50483    5826160            20.0             249.0      56.5     F        2.0
# 50484    8739285            19.0             229.0      69.5     F        2.0
# 50485    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 50481   372100.59           6.0            9.0      Test
# 50482  4279873.38           6.0            9.0   Control
# 50483    44837.16           2.0            5.0      Test
# 50484    44994.24           1.0            4.0      Test
# 50485   209278.15           0.0            3.0      Test
#
# [50486 rows x 10 columns]

# %%
#Exporting clean dataframes to csv

df_footprint.to_csv('df_footprint.csv', index=False)

df_users.to_csv('df_users.csv', index=False)

df_exp.to_csv('df_exp_clean.csv', index=False)

df_sample_client.to_csv('df_sample_client_clean.csv', index=False)

df_sample_fp.to_csv('df_sample_fp_clean.csv', index=False)

# %% [markdown]
# ## Sample analysis

# %%
df_users.groupby(['gendr'])['client_id'].count()
# Out:
# gendr
# F    22746
# M    23724
# U    24122
# X        3
# Name: client_id, dtype: int64

# %%
df_sample_client.groupby(['variation','gendr'])['client_id'].count()
# Out:
# variation  gendr
# Control    F        7543
#            M        7970
#            U        8014
# Test       F        8716
#            M        8977
#            U        9266
# Name: client_id, dtype: int64

# %%
df_sample_client.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth variation
# 0   45105.30           6.0            9.0      Test
# 1  110860.30           6.0            9.0   Control
# 2   52467.79           6.0            9.0      Test
# 3   67454.65           3.0            6.0      Test
# 4  103671.75           0.0            3.0   Control

# %%
plt.figure()
#sns.histplot(df_sample_client, x="clnt_tenure_yr")
#kde keyword adds a line that represents the shape of the histogram
sns.histplot(df_sample_client, x="clnt_tenure_yr",kde=True)
sns.histplot(df_users, x="clnt_tenure_yr", kde=True)
# Out:
# <AxesSubplot: xlabel='clnt_tenure_yr', ylabel='Count'>

# %%
sns.histplot(df_sample_client, x="gendr")
# Out:
# <AxesSubplot: xlabel='gendr', ylabel='Count'>

# %%
sns.histplot(df_sample_client, x="clnt_age")
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %%
sns.histplot(df_users, x="clnt_age")
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %%
plt.figure()
#sns.histplot(df_sample_client, x="clnt_tenure_yr")
#kde keyword adds a line that represents the shape of the histogram
sns.histplot(df_sample_client, x="clnt_age",kde=True)
sns.histplot(df_users, x="clnt_age", kde=True)
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %%
df_sample_client['clnt_tenure_yr'].describe()
# Out:
# count    50486.000000
# mean        12.031811
# std          6.860403
# min          2.000000
# 25%          6.000000
# 50%         11.000000
# 75%         16.000000
# max         55.000000
# Name: clnt_tenure_yr, dtype: float64

# %%
df_users['clnt_tenure_yr'].describe()
# Out:
# count    70595.000000
# mean        12.052950
# std          6.871819
# min          2.000000
# 25%          6.000000
# 50%         11.000000
# 75%         16.000000
# max         62.000000
# Name: clnt_tenure_yr, dtype: float64

# %%
print(df_sample_client['clnt_age'].describe())

print(df_users['clnt_age'].describe())
# Out:
# count    50485.000000
# mean        47.320362
# std         15.518599
# min         17.000000
# 25%         33.500000
# 50%         48.000000
# 75%         59.500000
# max         96.000000
# Name: clnt_age, dtype: float64
# count    70594.000000
# mean        46.442240
# std         15.591273
# min         13.500000
# 25%         32.500000
# 50%         47.000000
# 75%         59.000000
# max         96.000000
# Name: clnt_age, dtype: float64

# %%
print(df_sample_client['bal'].describe())

print(df_users['bal'].describe())
# Out:
# count    5.048600e+04
# mean     1.495195e+05
# std      3.020414e+05
# min      2.378944e+04
# 25%      3.988059e+04
# 50%      6.573557e+04
# 75%      1.399602e+05
# max      1.632004e+07
# Name: bal, dtype: float64
# count    7.059500e+04
# mean     1.474452e+05
# std      3.015087e+05
# min      1.378942e+04
# 25%      3.734683e+04
# 50%      6.333290e+04
# 75%      1.375449e+05
# max      1.632004e+07
# Name: bal, dtype: float64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=69aefbff-9953-4085-83bf-8937b918b827' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
