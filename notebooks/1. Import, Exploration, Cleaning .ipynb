# %% [markdown]
# # 1. Data import

# %% [markdown]
# ## Importing the dataframes

# %% [markdown]
# Let's import the necessary libraries we're gonna run through

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Here, we import functions we created in a previous notebook, so we can clean / reformat the column headers

# %%
# importing project_functions we created in a specific notebook
import importlib
import project_functions

importlib.reload(project_functions)
# Out:
# <module 'project_functions' from '/root/work/project_functions.py'>

# %%
# cleaning the columns : changing the columns headers to correct format
# for more information about this function --> cf project_functions.py notebook
clean_my_columns = project_functions.clean_my_columns

# %% [markdown]
# Now, we 'instance' our dataframes so we precise to Python to read them:

# %%
# df creation
# reading the various datasets:
df_pt1 = pd.read_csv('df_final_web_data_pt_1.txt')
df_pt2 = pd.read_csv('df_final_web_data_pt_2.txt')
df_users =pd.read_csv('df_final_demo.txt')
df_exp =pd.read_csv('df_final_experiment_clients.txt')

# %%
clean_my_columns(df_exp)

clean_my_columns(df_users)

clean_my_columns(df_pt1)

clean_my_columns(df_pt2)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# 1           confirm  2017-06-01 11:59:27
# 2            step_3  2017-06-01 11:58:48
# 3            step_2  2017-06-01 11:58:08
# 4            step_1  2017-06-01 11:57:58
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %% [markdown]
# We can also add breaklines in the output so it's more visual and easirer to view the results:

# %%
#Defining breaklines (useful for outputs results):

def breakline():
    print('\n')

def breakline2():
    print('\n'*2)

def breakline_dashes():
    print('---------------------------')

# %% [markdown]
# ## Looking at the dataframes

# %% [markdown]
# ### df_exp

# %% [markdown]
# The exp dataframe states whether a client (client_id) is being redirected on the original version (control) or to the new version (test)

# %%
display(df_exp)
# Out:
#        client_id variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_exp.shape
# Out:
# (70609, 2)

# %% [markdown]
# ### df1 + df2 -->  footprint

# %%
df_pt1.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
df_pt2.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %%
# Combining df_pt_1 and df_pt_2:
df_footprint=pd.concat([df_pt1,df_pt2])

#having a view of the table
df_footprint.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
print(f"shape of pt1: {df_pt1.shape}")
print(f"shape of pt2: {df_pt2.shape}")
print(f"shape of the concat: {df_footprint.shape}")
# Out:
# shape of pt1: (343141, 5)
# shape of pt2: (412264, 5)
# shape of the concat: (755405, 5)

# %%
# Number of clients
df_footprint['client_id'].nunique()
# Out:
# 120157

# %% [markdown]
# --> out of the 755405 rows of df_footprint, we have 120157 distinct client_ids (15,91 %)

# %% [markdown]
# ### df_users

# %%
display(df_users)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %% [markdown]
# --> Quick reminder of the various df KPIs

# %% [markdown]
# client_id: Every client’s unique ID.
# variation: Indicates if a client was part of the experiment.
# visitor_id: A unique ID for each client-device combination.
# visit_id: A unique ID for each web visit/session.
# process_step: Marks each step in the digital process.
# date_time: Timestamp of each web activity.
# clnt_tenure_yr: Represents how long the client has been with Vanguard, measured in years.
# clnt_tenure_mnth: Further breaks down the client’s tenure with Vanguard in months.
# clnt_age: Indicates the age of the client.
# gendr: Specifies the client’s gender.
# num_accts: Denotes the number of accounts the client holds with Vanguard.
# bal: Gives the total balance spread across all accounts for a particular client.
# calls_6_mnth: Records the number of times the client reached out over a call in the past six months.
# logons_6_mnth: Reflects the frequency with which the client logged onto Vanguard’s platform over the last six months

# %% [markdown]
# # Cleaning the dataframes

# %% [markdown]
# ## Cleaning df_exp table

# %% [markdown]
# Let's clean df_exp table:

# %% [markdown]
# ### Remove the 'NaN' rows

# %% [markdown]
# First, we remove the rows where NaN appear on the variation column:

# %% [markdown]
# More concretely, we remove the clients not participating to the A/B testing

# %%
#drop N/As from users dataframe

no_nulls=df_exp.dropna(subset = ['variation'], inplace=True)

# %%
#check shape
df_exp.shape
# Out:
# (50500, 2)

# %%
#check nulls again
df_exp.isna().sum()
# Out:
# client_id    0
# variation    0
# dtype: int64

# %% [markdown]
# ## Cleaning df_users

# %% [markdown]
# ### Filtering / sampling

# %% [markdown]
# Let's filter footprints to keep only clients from experiment

# %%
#creating new dataframe only with clients from clients list

clients_list = list(df_exp['client_id'])
clients_list

df_sample_client= df_users.loc[df_users['client_id'].isin(clients_list)]

df_sample_client.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
len(df_sample_client)
# Out:
# 50500

# %% [markdown]
# ### Null values cleaning

# %%
# list clients with null values

list_nulls = df_sample_client[df_sample_client.drop(columns=['client_id']).isnull().all(axis=1)]
len(list_nulls)
# Out:
# 12

# %%
#Let's now remove the clients with null values from our dataframe:
df_sample_client= df_sample_client.drop(df_sample_client[df_sample_client['client_id'].isin(list_nulls['client_id'])].index)
df_sample_client
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50496    6967120            21.0             260.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 50495   372100.59           6.0            9.0
# 50496  4279873.38           6.0            9.0
# 50497    44837.16           2.0            5.0
# 50498    44994.24           1.0            4.0
# 50499   209278.15           0.0            3.0
#
# [50488 rows x 9 columns]

# %%
# check for nulls in each column of df_sample_client
list_nulls.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      12
# clnt_tenure_mnth    12
# clnt_age            12
# gendr               12
# num_accts           12
# bal                 12
# calls_6_mnth        12
# logons_6_mnth       12
# dtype: int64

# %% [markdown]
# OK we're good for the client_ids

# %%
#list of clients with null values
list_nulls = df_sample_client[df_sample_client.drop(columns=['client_id']).isnull().all(axis=1)]
list_nulls
# Out:
# Empty DataFrame
# Columns: [client_id, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth]
# Index: []

# %%
df_sample_client.shape
# Out:
# (50488, 9)

# %%
# replace X gender withu U

df_sample_client['gendr'] = df_sample_client['gendr'].replace('X', 'U')

# %% [markdown]
# By doing such a thing, clients gender is either, male, female, or unknow so we now have two additionnal rows, these two rows being the one having X values

# %%
#new dimensions of the df_sample_client:
df_sample_client.shape
# Out:
# (50488, 9)

# %% [markdown]
# ## Cleaning df_footprint

# %% [markdown]
# ### Filtering / sampling

# %%
#create list of client_ids: 
clients_list2 = list(df_sample_client['client_id'])
clients_list2

#creating new dataframe with footprints only with clients from clients list
df_sample_fp = df_footprint.loc[df_footprint['client_id'].isin(clients_list2)]

df_sample_fp.shape
# Out:
# (321207, 5)

# %%
# merge dataframes sample_client with experiment clients

df_sample_client = df_sample_client.merge(df_exp, on='client_id', how='left')

# %%
#lowering the columns:
df_sample_client.columns = df_sample_client.columns.str.lower()

# %%
display(df_sample_client) # df_sample_client
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50483    1780858            21.0             262.0      68.5     M        3.0
# 50484    6967120            21.0             260.0      68.5     M        3.0
# 50485    5826160            20.0             249.0      56.5     F        2.0
# 50486    8739285            19.0             229.0      69.5     F        2.0
# 50487    7468138            18.0             222.0      61.0     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 50483   372100.59           6.0            9.0      Test
# 50484  4279873.38           6.0            9.0   Control
# 50485    44837.16           2.0            5.0      Test
# 50486    44994.24           1.0            4.0      Test
# 50487   209278.15           0.0            3.0      Test
#
# [50488 rows x 10 columns]

# %% [markdown]
# # Exporting our cleaned dataframes

# %%
#Exporting clean dataframes to csv

df_footprint.to_csv('df_footprint.csv', index=False)

df_users.to_csv('df_users.csv', index=False)

df_exp.to_csv('df_exp_clean.csv', index=False)

df_sample_client.to_csv('df_sample_client_clean.csv', index=False)

df_sample_fp.to_csv('df_sample_fp_clean.csv', index=False)

# %% [markdown]
# # Client behavior analysis

# %% [markdown]
# ## Sample analysis

# %%
df_sample_client.groupby(['gendr'])['client_id'].count()
# Out:
# gendr
# F    16259
# M    16947
# U    17282
# Name: client_id, dtype: int64

# %%
df_sample_client.groupby(['variation','gendr'])['client_id'].count()
# Out:
# variation  gendr
# Control    F        7543
#            M        7970
#            U        8014
# Test       F        8716
#            M        8977
#            U        9268
# Name: client_id, dtype: int64

# %%
df_sample_client.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth variation
# 0   45105.30           6.0            9.0      Test
# 1  110860.30           6.0            9.0   Control
# 2   52467.79           6.0            9.0      Test
# 3   67454.65           3.0            6.0      Test
# 4  103671.75           0.0            3.0   Control

# %% [markdown]
# ## Graphs / Viz

# %%
plt.figure()
#sns.histplot(df_sample_client, x="clnt_tenure_yr")
#kde keyword adds a line that represents the shape of the histogram
sns.histplot(df_sample_client, x="clnt_tenure_yr",kde=True)
sns.histplot(df_users, x="clnt_tenure_yr", kde=True)
# Out:
# <AxesSubplot: xlabel='clnt_tenure_yr', ylabel='Count'>

# %%
sns.histplot(df_sample_client, x="gendr")
# Out:
# <AxesSubplot: xlabel='gendr', ylabel='Count'>

# %%
sns.histplot(df_sample_client, x="clnt_age")
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %%
sns.histplot(df_users, x="clnt_age")
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
#sns.histplot(df_sample_client, x="clnt_tenure_yr")
#kde keyword adds a line that represents the shape of the histogram
sns.histplot(df_sample_client, x="clnt_age",kde=True)
sns.histplot(df_users, x="clnt_age", kde=True)
# Out:
# <AxesSubplot: xlabel='clnt_age', ylabel='Count'>

# %% [markdown]
# ## Additionnal observations

# %%
df_sample_client['clnt_tenure_yr'].describe()
# Out:
# count    50488.000000
# mean        12.031730
# std          6.860282
# min          2.000000
# 25%          6.000000
# 50%         11.000000
# 75%         16.000000
# max         55.000000
# Name: clnt_tenure_yr, dtype: float64

# %%
df_users['clnt_tenure_yr'].describe()
# Out:
# count    70595.000000
# mean        12.052950
# std          6.871819
# min          2.000000
# 25%          6.000000
# 50%         11.000000
# 75%         16.000000
# max         62.000000
# Name: clnt_tenure_yr, dtype: float64

# %%
print(df_sample_client['clnt_age'].describe())

print(df_users['clnt_age'].describe())
# Out:
# count    50487.000000
# mean        47.319795
# std         15.518616
# min         17.000000
# 25%         33.500000
# 50%         48.000000
# 75%         59.500000
# max         96.000000
# Name: clnt_age, dtype: float64
# count    70594.000000
# mean        46.442240
# std         15.591273
# min         13.500000
# 25%         32.500000
# 50%         47.000000
# 75%         59.000000
# max         96.000000
# Name: clnt_age, dtype: float64

# %%
print(df_sample_client['bal'].describe())

print(df_users['bal'].describe())
# Out:
# count    5.048800e+04
# mean     1.495147e+05
# std      3.020364e+05
# min      2.378944e+04
# 25%      3.987841e+04
# 50%      6.573360e+04
# 75%      1.399565e+05
# max      1.632004e+07
# Name: bal, dtype: float64
# count    7.059500e+04
# mean     1.474452e+05
# std      3.015087e+05
# min      1.378942e+04
# 25%      3.734683e+04
# 50%      6.333290e+04
# 75%      1.375449e+05
# max      1.632004e+07
# Name: bal, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.histplot(df_sample_client, x="clnt_tenure_yr",kde=True)
sns.histplot(df_users, x="clnt_tenure_yr", kde=True)
# Out:
# <AxesSubplot: xlabel='clnt_tenure_yr', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))
sns.histplot(df_sample_client, x="gendr")
sns.histplot(df_users, x="gendr")
# Out:
# <AxesSubplot: xlabel='gendr', ylabel='Count'>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=69aefbff-9953-4085-83bf-8937b918b827' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
